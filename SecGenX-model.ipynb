# %%
# Import thư viện
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv('vulnerability_fix_dataset.csv')
df.head()
# Out:
#   vulnerability_type                                    vulnerable_code  \
# 0      SQL Injection  import java.sql.*;\n\npublic class SQLInjectio...
# 1      SQL Injection  import java.sql.*;\n\npublic class VulnerableS...
# 2      SQL Injection  import java.sql.*;\n\npublic class SQLInjectio...
# 3      SQL Injection  import java.sql.Connection;\nimport java.sql.D...
# 4      SQL Injection  import java.sql.*;\n\npublic class VulnerableC...
#
#                                           fixed_code
# 0  import java.sql.*;\n\npublic class SQLInjectio...
# 1  import java.sql.*;\n\npublic class SecureSQLIn...
# 2  To prevent SQL Injection attacks in the provid...
# 3  To fix the SQL Injection vulnerability in the ...
# 4  import java.sql.*;\n\npublic class SecureCode ...

# %%
df.shape
# Out:
# (35000, 3)
